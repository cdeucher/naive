# %%
from collections import Counter, defaultdict
from machine_learning import split_data
from utils import savex, loadx

import math, random, re, glob
import numpy as np
import pandas as pd
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-39-a954d9180ac5> in <module>
#       1 from collections import Counter, defaultdict
#       2 from machine_learning import split_data
# ----> 3 from utils import savex, loadx
#       4
#       5 import math, random, re, glob
#
# ImportError: cannot import name 'savex' from 'utils' (/opt/notebooks/naive_bayes_assignment-master/utils.py)

# %%
import nltk
nltk.download()
##  d
##  punkt
##  words
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import words

ps = PorterStemmer()

# %%
def tokenize(message):
    message = message.lower() # convert to lowercase
    all_words = re.findall("[a-z0-9']+", message) # extract the words
    return set(all_words) # remove duplicates

# %%
def count_words(training_set):
    """training set consists of pairs (message, is_spam)"""
    counts = defaultdict(lambda: [0, 0])
    for message, is_spam in training_set:
        for word in tokenize(message):
            counts[word][0 if is_spam else 1] += 1
    return counts

# %%
def word_probabilities(counts, total_spams, total_non_spams, k=0.5):
    """turn the word_counts into a list of triplets
    w, p(w | spam) and p(w | ~spam)"""
    return [(w,
        (spam + k) / (total_spams + 2 * k),
        (non_spam + k) / (total_non_spams + 2 * k))
            for w, (spam, non_spam) in counts.items()]

# %%
def spam_probability(word_probs, message):
    message_words = tokenize(message)
    log_prob_if_spam = log_prob_if_not_spam = 0.0

    for word, prob_if_spam, prob_if_not_spam in word_probs:

        # for each word in the message,
        # add the log probability of seeing it
        if word in message_words:
            log_prob_if_spam += math.log(prob_if_spam)
            log_prob_if_not_spam += math.log(prob_if_not_spam)

        # for each word that's not in the message
        # add the log probability of _not_ seeing it
        else:
            log_prob_if_spam += math.log(1.0 - prob_if_spam)
            log_prob_if_not_spam += math.log(1.0 - prob_if_not_spam)

    result = 0    
    try:
       result = prob_if_spam / (prob_if_spam + prob_if_not_spam)
    except:
       print('spam_probability',message, prob_if_spam , prob_if_spam , prob_if_not_spam)
    
    return result

# %%
class NaiveBayesClassifier:

    def __init__(self, k=0.5):
        self.k = k
        self.word_probs = []

    def train(self, training_set):

        # count spam and non-spam messages
        num_spams = len([is_spam
                         for message, is_spam in training_set
                         if is_spam])
        num_non_spams = len(training_set) - num_spams

        # run training data through our "pipeline"
        word_counts = count_words(training_set)
        self.word_probs = word_probabilities(word_counts,
                                             num_spams,
                                             num_non_spams,
                                             self.k)

    def classify(self, message):
        return spam_probability(self.word_probs, message)

# %%
def is_html(line):
    batRegex = re.compile(r'(<[^>]+>|^\s|@|^http:|style=|face=|&nbsp;|SIZE|TABLE|META|http|><|^X-|^--|^Errors-|th=|^Content-|^Mime-|^MIME-|^Sender|^charset|^Date:)')
    tag = batRegex.search(line)
    #print(line, tag)
    return tag

# %%
def filters(line):   
    clear     = ' '
    separator = ', '
    sentence  = []
        
    line.lower()
    arr_words = word_tokenize(line)

    for w in arr_words:
    #if w in words.words() :            
        sentence.append(ps.stem(w))
    #endFor
    
    print('sentence',sentence)
    clear = separator.join(sentence)
    clear = re.sub(',', '', clear)
    print('clear',clear)
    
    return clear

# %%
def get_subject_data(path):

    data = []

    # regex for stripping out the leading "Subject:" and any spaces after it
    subject_regex = re.compile(r"^Subject:\s+")

    # glob.glob returns every filename that matches the wildcarded path
    for fn in glob.glob(path):
        is_spam = "ham" not in fn

        with open(fn,'r',encoding='ISO-8859-1') as file:
            start = False
            for line in file:         
                if line.startswith("Subject:"):
                    subject = subject_regex.sub("", line).strip()
                    print(subject)
                    print()
                    print()
                    subject = filters(subject)
                    print(subject)
                    print()
                    print()                    
                    data.append((subject, is_spam))                    
                    start = True
                elif start == True  and is_html(line) == None:
                    subject = subject_regex.sub("", line).strip()
                    subject = filters(subject)
                    data.append((subject, is_spam))                    

    return data

# %%
def p_spam_given_word(word_prob):
    word, prob_if_spam, prob_if_not_spam = word_prob
    return prob_if_spam / (prob_if_spam + prob_if_not_spam)

# %%
def train_and_test_model(path):

    data = get_subject_data(path)
    random.seed(0)      # just so you get the same answers as me
    train_data, test_data = split_data(data, 0.75)

    classifier = NaiveBayesClassifier()
    classifier.train(train_data)

    classified = [(subject, is_spam, classifier.classify(subject))
              for subject, is_spam in test_data]

    counts = Counter((is_spam, spam_probability > 0.5) # (actual, predicted)
                     for _, is_spam, spam_probability in classified)

    print() 
    print(counts)
    print()
    
    classified.sort(key=lambda row: row[2])
    spammiest_hams = list(filter(lambda row: not row[1], classified))[-5:]
    hammiest_spams = list(filter(lambda row: row[1], classified))[:5]

    print("spammiest_hams", spammiest_hams)
    print()
    print("hammiest_spams", hammiest_spams)
    print()
    
    words = sorted(classifier.word_probs, key=p_spam_given_word)

    spammiest_words = words[-5:]
    hammiest_words = words[:5]

    print("spammiest_words", spammiest_words)
    print()    
    print("hammiest_words", hammiest_words)
    print()

# %%
if __name__ == "__main__":
    #train_and_test_model(r"./emails/*/*")
    train_and_test_model(r"./test/*/*")
# Out:
# CNET NEWS.COM: Cable companies cracking down on Wi-Fi
#
#
# sentence ['crack', 'down', 'on']
# clear crack down on
# crack down on
#
#
# sentence ['are', 'crack', 'down', 'on', 'popular', 'threaten', 'to', 'cut', 'servic', 'to', 'who', 'set', 'up', 'the', 'inexpens', 'wireless', 'and', 'allow', 'to', 'freeli', 'tap', 'into', 'their', 'access']
# clear are crack down on popular threaten to cut servic to who set up the inexpens wireless and allow to freeli tap into their access
# sentence ['of', 'given', 'less', 'than', 'a', 'week', 'to', 'stop', 'their', 'to', 'provid', 'a', 'wireless', 'local', 'area', 'network', 'avail', 'to', 'anyon', 'within', 'the', 'are', 'just', 'an', 'initi', 'volley', 'to', 'send', 'addit', 'while', 'T', 'also', 'is', 'similar', 'for', 'some', 'of', 'it']
# clear of given less than a week to stop their to provid a wireless local area network avail to anyon within the are just an initi volley to send addit while T also is similar for some of it
# sentence ['juli']
# clear juli
# sentence ['have', 'recent', 'been', 'given', 'access', 'to', 'the', 'popular', 'music', 'player', 'and', 'now', 'may', 'soon', 'be', 'abl', 'to', 'take', 'a', 'bite', 'out', 'of', 'gadget', 'week', 'a', 'small', 'compani', 'in', 'san', 'francisco', 'beta', 'test', 'an', 'for', 'it', 'music', 'player', 'which', 'is', 'itself', 'a', 'clone', 'of', 'the', 'will', 'allow', 'access', 'to', 'which', 'up', 'to', 'of', 'music']
# clear have recent been given access to the popular music player and now may soon be abl to take a bite out of gadget week a small compani in san francisco beta test an for it music player which is itself a clone of the will allow access to which up to of music
# sentence ['juli']
# clear juli
# sentence ['to', 'be', 'move', 'toward', 'sell', 'it', 'own']
# clear to be move toward sell it own
# sentence ['A', 'pair', 'of', 'analyst', 'tuesday', 'ad', 'to', 'a', 'torrent', 'of', 'recent', 'specul', 'that', 'the', 'maker', 'next', 'move', 'will', 'be', 'into', 'the', 'printer', 'market', 'into', 'a', 'number', 'of', 'new', 'over', 'the', 'past', 'few']
# clear A pair of analyst tuesday ad to a torrent of recent specul that the maker next move will be into the printer market into a number of new over the past few
# sentence ['to', 'extend', 'it', 'identif', 'system', 'into', 'credit', 'card']
# clear to extend it identif system into credit card
# sentence ['the', 'giant', 'will', 'strike', 'a', 'partnership', 'tuesday', 'with', 'maker', 'which', 'payment', 'for', 'and', 'for', 'that', 'issu', 'and', 'credit', 'the', 'behind', 'own', 'by', 'program', 'as', 'well', 'as', 'a', 'similar', 'program', 'in', 'develop', 'at']
# clear the giant will strike a partnership tuesday with maker which payment for and for that issu and credit the behind own by program as well as a similar program in develop at
# sentence ['juli']
# clear juli
# sentence ['A', 'feder', 'judg', 'said', 'monday', 'that', 'record', 'and', 'film', 'could', 'expand', 'an', 'ongo', 'copyright', 'lawsuit', 'to', 'includ', 'which', 'the', 'popular']
# clear A feder judg said monday that record and film could expand an ongo copyright lawsuit to includ which the popular
# sentence ['the', 'of', 'america', 'and', 'the', 'of', 'america', 'three', 'promin', 'in', 'octob', 'in', 'feder', 'court', 'the', 'suit', 'morpheu', 'parent', 'and', 'the', 'compani', 'that', 'origin', 'the']
# clear the of america and the of america three promin in octob in feder court the suit morpheu parent and the compani that origin the
# sentence ['juli']
# clear juli
# sentence ['slump', 'tech', 'to', 'tap', 'the', 'sleep', 'giant', 'prowess', 'and', 'consum', 'market']
# clear slump tech to tap the sleep giant prowess and consum market
# sentence ['juli']
# clear juli
# sentence []
# clear
# sentence ['may', 'again', 'have', 'of', 'excess', 'goodwil', 'on', 'it', 'and', 'a', 'wo', 'go', 'over', 'well', 'with', 'alreadi', 'unhappi']
# clear may again have of excess goodwil on it and a wo go over well with alreadi unhappi
# sentence ['juli']
# clear juli
# sentence []
# clear
# sentence ['juli']
# clear juli
# Save an extra $50 on the iPaq 3835 PDA (CNET SHOPPER)
#
#
# sentence ['an', 'extra', 'on', 'the']
# clear an extra on the
# an extra on the
#
#
# sentence ['ani', 'new', 'on', 'or', 'befor', 'juli', 'and', 'you']
# clear ani new on or befor juli and you
# sentence ['be', 'automat', 'to', 'win', 'the', 'next', 'lucki', 'winner']
# clear be automat to win the next lucki winner
# sentence ['could', 'be', 'you']
# clear could be you
# This week: Deck, Tex-Edit Plus, Boom
#
#
# sentence ['week']
# clear week
# week
#
#
# sentence ['mac']
# clear mac
# sentence ['juli']
# clear juli
# sentence ['No']
# clear No
# sentence ['a', 'mac', 'and', 'today', 'music', 'are', 'find']
# clear a mac and today music are find
# sentence ['that', 'they', 'can', 'creat', 'record', 'and', 'master', 'their', 'without']
# clear that they can creat record and master their without
# sentence ['the', 'need', 'to', 'pay', 'for', 'expens', 'studio', 'time', 'our', 'of']
# clear the need to pay for expens studio time our of
# sentence ['the', 'a', 'audio', 'that', 'can', 'take']
# clear the a audio that can take
# sentence ['care', 'of', 'all', 'your', 'record', 'need', 'and', 'it', 'even', 'for']
# clear care of all your record need and it even for
# sentence ['X', 'just', 'great', 'for', 'music', 'can', 'be', 'use', 'for', 'film', 'video']
# clear X just great for music can be use for film video
# sentence ['and', 'numer', 'other', 'on']
# clear and numer other on
# sentence ['thi', 'week', 'we', 'got', 'for', 'an', 'easi', 'way', 'to']
# clear thi week we got for an easi way to
# sentence ['transfer', 'to', 'get', 'you', 'organ', 'under', 'X']
# clear transfer to get you organ under X
# sentence ['a', 'altern', 'to', 'the']
# clear a altern to the
# sentence ['text', 'and', 'a', 'remak', 'of', 'one', 'of', 'the', 'great', 'classic']
# clear text and a remak of one of the great classic
# sentence ['arcad']
# clear arcad
# sentence []
# clear
# sentence ['jason']
# clear jason
# sentence []
# clear
# sentence ['are', 'at', 'the', 'bottom', 'of', 'thi']
# clear are at the bottom of thi
# sentence ['newslett']
# clear newslett
# sentence ['start', 'at']
# clear start at
# sentence ['and', 'the', 'R', 'price', 'perform']
# clear and the R price perform
# sentence ['and', 'portabl', 'includ', 'R', 'R']
# clear and portabl includ R R
# sentence ['and', 'display']
# clear and display
# sentence ['and', 'your', 'choic', 'of', 'oper']
# clear and your choic of oper
# sentence []
# clear
# sentence []
# clear
# sentence ['of', 'the']
# clear of the
# sentence ['the', 'in']
# clear the in
# sentence []
# clear
# sentence ['the', 'in', 'mac', 'X']
# clear the in mac X
# sentence ['on']
# clear on
# sentence []
# clear
# sentence ['a', 'suggest', 'for', 'it', 'to']
# clear a suggest for it to
# sentence []
# clear
# sentence []
# clear
# sentence ['for', 'more', 'on', 'most', 'popular', 'click']
# clear for more on most popular click
# sentence []
# clear
# sentence ['of', 'the']
# clear of the
# sentence []
# clear
# sentence ['the', 'in']
# clear the in
# sentence []
# clear
# sentence ['on', 'of', 'and']
# clear on of and
# sentence []
# clear
# sentence ['the', 'in']
# clear the in
# sentence []
# clear
# sentence ['on']
# clear on
# sentence []
# clear
# sentence ['sign', 'up', 'for', 'more', 'click', 'here']
# clear sign up for more click here
# sentence ['click', 'here']
# clear click here
# sentence ['receiv', 'your', 'newslett', 'in', 'format', 'click', 'here']
# clear receiv your newslett in format click here
# sentence ['for', 'the', 'click', 'here']
# clear for the click here
# sentence ['learn', 'about', 'advertis', 'in', 'click', 'here']
# clear learn about advertis in click here
# sentence ['reserv']
# clear reserv
# Reg Headlines Wednesday July 10
#
#
# sentence ['wednesday', 'juli']
# clear wednesday juli
# wednesday juli
#
#
# sentence ['list']
# clear list
# sentence ['from', 'the']
# clear from the
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence ['the', 'mac']
# clear the mac
# sentence []
# clear
# sentence ['the']
# clear the
# sentence []
# clear
# sentence ['the', 'and', 'it', 'content', 'are', 'copyright']
# clear the and it content are copyright
# sentence ['reserv']
# clear reserv
# sentence ['from', 'these', 'daili', 'visit', 'the', 'follow']
# clear from these daili visit the follow
# sentence ['sure', 'that', 'you', 'enter', 'exactli', 'the', 'same', 'address', 'as', 'you', 'use', 'to', 'join']
# clear sure that you enter exactli the same address as you use to join
# sentence ['thi', 'servic']
# clear thi servic
# [Lockergnome Penguin Shell]  Recursive Metaphor
#
#
# sentence []
# clear
#
#
#
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence ['solid', 'solid']
# clear solid solid
# sentence ['solid']
# clear solid
# sentence ['solid', 'solid']
# clear solid solid
# sentence ['solid']
# clear solid
# sentence ['solid', 'solid']
# clear solid solid
# sentence ['solid']
# clear solid
# sentence ['solid', 'solid']
# clear solid solid
# sentence ['solid', 'bold']
# clear solid bold
# sentence ['pad', 'width']
# clear pad width
# sentence ['bodi']
# clear bodi
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence ['middl', 'center']
# clear middl center
# sentence []
# clear
# sentence ['tabl']
# clear tabl
# sentence ['to', 'bring', 'you', 'a', 'full', 'servic', 'career', 'enhanc', 'solut']
# clear to bring you a full servic career enhanc solut
# sentence ['you', 'are', 'look', 'for', 'your']
# clear you are look for your
# sentence ['or', 'tri', 'to']
# clear or tri to
# sentence ['the', 'career', 'resourc', 'center', 'is', 'the', 'place', 'to', 'start', 'your']
# clear the career resourc center is the place to start your
# sentence ['today']
# clear today
# sentence ['I', 'do', 'usual', 'spend', 'much', 'time', 'explain', 'are', 'after', 'all']
# clear I do usual spend much time explain are after all
# sentence ['metaphor', 'can', 'be', 'fill', 'with', 'whatev', 'symbol', 'you', 'choos']
# clear metaphor can be fill with whatev symbol you choos
# sentence ['well', 'we', 'all', 'come', 'to', 'some', 'similar', 'understand', 'of', 'their', 'mean', 'I']
# clear well we all come to some similar understand of their mean I
# sentence ['depart', 'today', 'contrari', 'to', 'my', 'normal', 'practic', 'to', 'take', 'a', 'few', 'explain', 'a']
# clear depart today contrari to my normal practic to take a few explain a
# sentence ['I', 'a', 'guy', 'through', 'and', 'through', 'As', 'a', 'user', 'I', 'see', 'myself', 'as', 'right', 'about', 'at']
# clear I a guy through and through As a user I see myself as right about at
# sentence ['the', 'averag', 'on', 'the', 'curv', 'for', 'love', 'of', 'the', 'languag', 'and', 'open', 'sourc', 'attitud']
# clear the averag on the curv for love of the languag and open sourc attitud
# sentence ['though', 'you', 'be', 'to', 'find', 'anyon', 'with', 'quit', 'the', 'same', 'level', 'of']
# clear though you be to find anyon with quit the same level of
# sentence ['enthusiasm', 'simpli', 'there', 'veri', 'littl', 'about', 'the', 'and', 'open']
# clear enthusiasm simpli there veri littl about the and open
# sentence ['for', 'exampl', 'the', 'practic', 'of', 'recurs']
# clear for exampl the practic of recurs
# sentence ['of', 'an', 'even']
# clear of an even
# sentence ['all', 'carri', 'on', 'the', 'tradit', 'of', 'recurs', 'in', 'the']
# clear all carri on the tradit of recurs in the
# sentence ['it', 'is', 'that', 'I', 'set', 'out', 'to', 'creat', 'a', 'recurs', 'metaphor', 'last', 'week', 'could', 'onli']
# clear it is that I set out to creat a recurs metaphor last week could onli
# sentence ['have', 'on', 'or', 'about', 'the', 'of', 'juli', 'fact', 'it', 'in', 'the', 'edit']
# clear have on or about the of juli fact it in the edit
# sentence ['of', 'the', 'I', 'wrote', 'a', 'piec', 'about', 'how', 'we', 'spend', 'more', 'time', 'over', 'the']
# clear of the I wrote a piec about how we spend more time over the
# sentence ['right', 'I', 'wrote', 'it', 'know', 'full', 'well', 'that', 'mani', 'of', 'the', 'I', 'get', 'would', 'be']
# clear right I wrote it know full well that mani of the I get would be
# sentence ['a', 'from', 'outsid', 'the', 'and', 'b', 'in', 'sharp', 'disagr', 'to', 'my', 'or']
# clear a from outsid the and b in sharp disagr to my or
# sentence ['those', 'of', 'of', 'other', 'follow', 'me', 'right', 'would']
# clear those of of other follow me right would
# sentence ['disagre', 'with', 'an', 'articl', 'that', 'said', 'we', 'spend', 'much', 'time', 'of']
# clear disagre with an articl that said we spend much time of
# sentence ['cours', 'would', 'prove', 'my', 'point', 'in', 'a', 'somewhat', 'metaphor', 'way', 'the', 'perfect']
# clear cours would prove my point in a somewhat metaphor way the perfect
# sentence ['recurs', 'metaphor', 'the', 'point', 'wa', 'to', 'be', 'made', 'yet', 'more', 'perfectli', 'by', 'the', 'eventu']
# clear recurs metaphor the point wa to be made yet more perfectli by the eventu
# sentence ['with', 'my', 'take', 'our', 'argument', 'as', 'they', 'would']
# clear with my take our argument as they would
# sentence ['be', 'that', 'disagre', 'with', 'our', 'collect', 'american', 'percept', 'of', 'be']
# clear be that disagre with our collect american percept of be
# sentence ['disagre', 'would', 'of', 'cours', 'point', 'out', 'about', 'which', 'of']
# clear disagre would of cours point out about which of
# sentence ['other', 'can', 'disagre', 'with', 'on', 'the', 'right', 'to']
# clear other can disagre with on the right to
# sentence ['disagre', 'we', 'subtli', 'agre', 'that', 'we', 'have', 'that', 'right', 'anoth', 'level', 'of']
# clear disagre we subtli agre that we have that right anoth level of
# sentence ['the', 'respons', 'to', 'both', 'my', 'own', 'and', 'johan', 'wa', 'overwhelm']
# clear the respons to both my own and johan wa overwhelm
# sentence ['the', 'main', 'I', 'believ', 'both', 'were', 'on', 'the', 'balanc', 'of', 'the']
# clear the main I believ both were on the balanc of the
# sentence ['two', 'were', 'I', 'think', 'to', 'see', 'a', 'dissent', 'opinion']
# clear two were I think to see a dissent opinion
# sentence ['so', 'quickli', 'if', 'at', 'all', 'the', 'abil', 'to', 'express', 'honestli']
# clear so quickli if at all the abil to express honestli
# sentence ['to', 'agre', 'and', 'to', 'disagre', 'on', 'a', 'global', 'level', 'close', 'the', 'circl', 'on', 'the']
# clear to agre and to disagre on a global level close the circl on the
# sentence ['have', 'howev', 'gotten', 'a', 'bit', 'more', 'ugli', 'in', 'the', 'past', 'few', 'day', 'I', 'not', 'sure']
# clear have howev gotten a bit more ugli in the past few day I not sure
# sentence ['whether', 'some', 'were', 'slow', 'in', 'get', 'to', 'the', 'juli', 'issu', 'or', 'whether', 'it', 'just']
# clear whether some were slow in get to the juli issu or whether it just
# sentence ['been', 'sinc', 'then', 'for', 'instanc', 'these', 'by', 'a', 'reader', 'who', 'will']
# clear been sinc then for instanc these by a reader who will
# sentence ['remain', 'merci', 'nameless']
# clear remain merci nameless
# sentence ['get', 'enough']
# clear get enough
# sentence ['america', 'from', 'our', 'extremist', 'press', 'and', 'here']
# clear america from our extremist press and here
# sentence ['in', 'the', 'that', 'we', 'do', 'wish', 'to', 'hear', 'some', 'insert', 'favorit', 'adject', 'here']
# clear in the that we do wish to hear some insert favorit adject here
# sentence ['from', 'too']
# clear from too
# sentence ['by']
# clear by
# sentence ['pleas', 'do', 'let', 'toni', 'tarnish', 'the', 'fine', 'reput']
# clear pleas do let toni tarnish the fine reput
# sentence ['of', 'I', 'sure', 'there', 'are', 'other', 'articul', 'out', 'there', 'who']
# clear of I sure there are other articul out there who
# sentence ['would', 'be', 'abl', 'to', 'replac', 'him']
# clear would be abl to replac him
# sentence ['and', 'in', 'a', 'later', 'note', 'on', 'the', 'topic']
# clear and in a later note on the topic
# sentence ['is', 'to', 'be', 'in', 'a']
# clear is to be in a
# sentence ['societi', 'whenev', 'and', 'wherev', 'it', 'doe', 'come', 'from', 'the']
# clear societi whenev and wherev it doe come from the
# sentence ['govern']
# clear govern
# sentence ['been', 'great', 'about', 'all', 'hi', 'plenti', 'of', 'room', 'in', 'the', 'editori']
# clear been great about all hi plenti of room in the editori
# sentence ['piec', 'at', 'the', 'begin', 'of', 'each', 'newslett', 'particular', 'piec', 'is', 'no']
# clear piec at the begin of each newslett particular piec is no
# sentence ['except', 'shown', 'a', 'quiet', 'confid', 'in', 'the', 'face', 'of', 'some', 'veri', 'shrill']
# clear except shown a quiet confid in the face of some veri shrill
# sentence ['we', 'all', 'gener', 'stay', 'on', 'technic', 'chri']
# clear we all gener stay on technic chri
# sentence ['shown', 'unwav', 'support', 'for', 'the', 'notion', 'that', 'we', 'are', 'in', 'the', 'end']
# clear shown unwav support for the notion that we are in the end
# sentence ['with', 'and', 'to', 'share', 'I', 'think', 'it', 'one', 'of', 'the', 'that']
# clear with and to share I think it one of the that
# sentence ['despit', 'the', 'irration', 'of', 'some', 'of', 'thi', 'week', 'I', 'continu', 'to']
# clear despit the irration of some of thi week I continu to
# sentence ['watch', 'out', 'are', 'onli', 'funni', 'until', 'someon', 'an', 'eye']
# clear watch out are onli funni until someon an eye
# sentence ['toni']
# clear toni
# sentence ['you', 'look', 'for', 'the', 'ultim', 'resourc', 'the']
# clear you look for the ultim resourc the
# sentence ['for']
# clear for
# sentence ['a']
# clear a
# sentence ['I', 'an', 'interest', 'review', 'of', 'two', 'for', 'by', 'a']
# clear I an interest review of two for by a
# sentence ['and', 'probabl', 'of', 'both', 'by', 'now', 'as', 'they']
# clear and probabl of both by now as they
# sentence ['quit', 'a', 'bit', 'of', 'public', 'both', 'in', 'and', 'out', 'of', 'the', 'world']
# clear quit a bit of public both in and out of the world
# sentence ['recal', 'that', 'I', 'to', 'tri', 'to', 'secur', 'for', 'review', 'thi', 'week', 'the']
# clear recal that I to tri to secur for review thi week the
# sentence ['help', 'of', 'a', 'friendli', 'rep', 'at', 'I', 'wa', 'abl', 'to', 'accomplish', 'that', 'task']
# clear help of a friendli rep at I wa abl to accomplish that task
# sentence ['thi', 'morn', 'to', 'the', 'second', 'half', 'of', 'the', 'promis', 'we', 'spend', 'the', 'next', 'few']
# clear thi morn to the second half of the promis we spend the next few
# sentence ['day', 'look', 'at', 'these', 'two', 'and', 'how', 'they', 'might', 'impact', 'your', 'use']
# clear day look at these two and how they might impact your use
# sentence ['A', 'bit', 'of', 'background', 'is', 'in', 'order', 'is', 'in', 'their', 'own', 'the']
# clear A bit of background is in order is in their own the
# sentence ['ongo', 'project', 'to', 'port', 'to', 'a', 'tough', 'goal', 'but']
# clear ongo project to port to a tough goal but
# sentence ['slow', 'the', 'project', 'to', 'stay', 'at', 'the', 'front', 'of', 'thi', 'develop']
# clear slow the project to stay at the front of thi develop
# sentence ['releas', 'had', 'taken', 'a', 'full', 'system', 'approach']
# clear releas had taken a full system approach
# sentence ['in', 'the', 'instal', 'of', 'a', 'sizeabl', 'daemon', 'and', 'no', 'small', 'amount', 'of']
# clear in the instal of a sizeabl daemon and no small amount of
# sentence ['configur', 'work', 'away', 'from', 'the']
# clear configur work away from the
# sentence ['approach', 'to', 'one', 'that', 'much', 'more', 'modular', 'than', 'at', 'system']
# clear approach to one that much more modular than at system
# sentence ['is', 'with', 'the', 'virtual', 'path', 'to', 'the']
# clear is with the virtual path to the
# sentence ['program', 'the', 'program', 'is', 'close', 'so', 'is', 'on']
# clear program the program is close so is on
# sentence ['the', 'stand', 'as', 'a', 'clear', 'indic', 'that', 'the', 'chang', 'in', 'philosophi', 'is', 'a']
# clear the stand as a clear indic that the chang in philosophi is a
# sentence ['success', 'the', 'top', 'media']
# clear success the top media
# sentence ['and', 'into', 'a', 'browser']
# clear and into a browser
# sentence ['packag', 'in', 'more', 'esoter', 'like']
# clear packag in more esoter like
# sentence ['and', 'and', 'you', 'got', 'virtual', 'everi', 'need', 'need']
# clear and and you got virtual everi need need
# sentence ['thi', 'packag', 'doe', 'stop', 'there', 'in', 'the', 'packag']
# clear thi packag doe stop there in the packag
# sentence ['are', 'for', 'and', 'as', 'well', 'as', 'sever']
# clear are for and as well as sever
# sentence ['I', 'wa', 'at', 'the', 'rang', 'of']
# clear I wa at the rang of
# sentence ['had', 'some', 'experi', 'with', 'I', 'wa', 'a', 'bit', 'leeri', 'about', 'the', 'instal']
# clear had some experi with I wa a bit leeri about the instal
# sentence ['process', 'and', 'about', 'the', 'abil', 'to', 'get', 'all', 'these', 'great', 'to', 'work', 'with']
# clear process and about the abil to get all these great to work with
# sentence ['my', 'setup', 'I', 'never', 'been', 'complet', 'success', 'with', 'but', 'I', 'hope']
# clear my setup I never been complet success with but I hope
# sentence ['for', 'the', 'best', 'when', 'I', 'the', 'instal', 'I', 'realli', 'did', 'want']
# clear for the best when I the instal I realli did want
# sentence ['the', 'instal', 'wa', 'quit', 'easi', 'run', 'the', 'script', 'from']
# clear the instal wa quit easi run the script from
# sentence ['the', 'command', 'line', 'I', 'wa', 'abl', 'to', 'instal', 'the', 'for', 'both']
# clear the command line I wa abl to instal the for both
# sentence ['and', 'which', 'we', 'talk', 'about', 'tomorrow', 'I', 'the']
# clear and which we talk about tomorrow I the
# sentence ['with', 'a', 'tool', 'I', 'admittedli', 'in', 'the']
# clear with a tool I admittedli in the
# sentence ['background', 'had', 'alreadi', 'a', 'virtual', 'C', 'drive', 'on', 'my']
# clear background had alreadi a virtual C drive on my
# sentence ['machin', 'I', 'on', 'the', 'instal', 'and', 'immedi', 'saw', 'a', 'familiar', 'sight']
# clear machin I on the instal and immedi saw a familiar sight
# sentence ['the', 'instal', 'in', 'it', 'format', 'first', 'check', 'for']
# clear the instal in it format first check for
# sentence ['feedback', 'from', 'the', 'binari', 'a', 'virtual', 'window', 'then', 'step']
# clear feedback from the binari a virtual window then step
# sentence ['out', 'while', 'the', 'instal', 'took', 'care', 'of', 'the', 'rest', 'the', 'instal']
# clear out while the instal took care of the rest the instal
# sentence ['four', 'time', 'it', 'to', 'be', 'a', 'server', 'failur', 'rather', 'than', 'a', 'failur', 'of', 'the']
# clear four time it to be a server failur rather than a failur of the
# sentence ['program', 'I', 'kept', 'retri', 'ing', 'and', 'with', 'some', 'persist', 'to', 'get']
# clear program I kept retri ing and with some persist to get
# sentence ['a', 'full', 'instal', 'from', 'the', 'liter']
# clear a full instal from the liter
# sentence ['the', 'instal', 'and', 'exactli', 'as', 'I', 'seem', 'mani', 'time', 'in']
# clear the instal and exactli as I seem mani time in
# sentence ['the', 'instal', 'wa', 'again', 'check', 'for', 'the', 'binari']
# clear the instal wa again check for the binari
# sentence ['the', 'appropri', 'in', 'the', 'virtual', 'C', 'drive', 'and', 'the']
# clear the appropri in the virtual C drive and the
# sentence ['into', 'the', 'and']
# clear into the and
# sentence ['the', 'process', 'wa', 'so', 'smooth', 'that', 'I', 'had', 'to', 'check', 'the', 'in', 'these']
# clear the process wa so smooth that I had to check the in these
# sentence ['enough', 'the']
# clear enough the
# sentence ['wa', 'list', 'I', 'ran', 'out', 'to', 'the', 'site', 'and', 'the']
# clear wa list I ran out to the site and the
# sentence ['I', 'with', 'the', 'media', 'and']
# clear I with the media and
# sentence ['those', 'the', 'onli', 'that', 'were', 'in', 'the']
# clear those the onli that were in the
# sentence ['instal', 'were', 'and', 'at', 'that', 'the', 'instal', 'point', 'me', 'to']
# clear instal were and at that the instal point me to
# sentence ['the', 'then', 'found', 'the', 'file', 'when', 'the', 'wa', 'done']
# clear the then found the file when the wa done
# sentence ['just', 'for', 'I', 'via', 'wa', 'despit']
# clear just for I via wa despit
# sentence ['the', 'recommend', 'in', 'the', 'instal', 'screen', 'to', 'use', 'the', 'version', 'went', 'as']
# clear the recommend in the instal screen to use the version went as
# sentence ['smoothli', 'as', 'the', 'with', 'one', 'caveat', 'the', 'player', 'media', 'at', 'a', 'much']
# clear smoothli as the with one caveat the player media at a much
# sentence ['faster', 'speed', 'than', 'that', 'in', 'enough', 'to', 'make', 'me', 'laugh', 'in', 'fact']
# clear faster speed than that in enough to make me laugh in fact
# sentence ['of', 'dave', 'and', 'alvin', 'the', 'Ah', 'well', 'six', 'out', 'of', 'seven', 'is', 'pretti']
# clear of dave and alvin the Ah well six out of seven is pretti
# sentence ['I', 'also', 'a', 'few', 'roman', 'and']
# clear I also a few roman and
# sentence ['alway', 'great', 'promis', 'time', 'it', 'been', 'pain', 'to', 'watch', 'the']
# clear alway great promis time it been pain to watch the
# sentence ['tediou', 'pace', 'of', 'develop', 'onli', 'becaus', 'that', 'promis', 'wa', 'so', 'allur', 'the']
# clear tediou pace of develop onli becaus that promis wa so allur the
# sentence ['back', 'of', 'and', 'a', 'fundament', 'chang', 'in', 'the', 'approach', 'to', 'develop']
# clear back of and a fundament chang in the approach to develop
# sentence ['final', 'the', 'goal', 'of']
# clear final the goal of
# sentence ['seamlessli', 'into', 'the', 'stabl', 'environ', 'the', 'are', 'so', 'strong', 'that', 'if']
# clear seamlessli into the stabl environ the are so strong that if
# sentence ['I', 'did', 'know', 'better', 'I', 'swear', 'that', 'a', 'few', 'of', 'these', 'actual', 'run', 'better']
# clear I did know better I swear that a few of these actual run better
# sentence ['in', 'than', 'in', 'their', 'nativ', 'I', 'did', 'realiz', 'how', 'much', 'I']
# clear in than in their nativ I did realiz how much I
# sentence ['a', 'few', 'with', 'a', 'look', 'at']
# clear a few with a look at
# sentence ['nine', 'into', 'the', 'kernel', 'configur', 'seri', 'with', 'quit', 'a', 'bit', 'yet', 'to']
# clear nine into the kernel configur seri with quit a bit yet to
# sentence ['go', 'you', 'have', 'been', 'follow', 'along', 'we', 'break', 'out', 'the', 'configur']
# clear go you have been follow along we break out the configur
# sentence ['one', 'at', 'a', 'time', 'in', 'an', 'attempt', 'to', 'shed', 'some', 'light', 'on', 'the', 'purpos', 'and']
# clear one at a time in an attempt to shed some light on the purpos and
# sentence ['function', 'of', 'each', 'that', 'knowledg', 'you', 'should', 'be', 'abl', 'to', 'make', 'a', 'clear']
# clear function of each that knowledg you should be abl to make a clear
# sentence ['it', 'the', 'support', 'section', 'is', 'pretti', 'simpl', 'you']
# clear it the support section is pretti simpl you
# sentence ['need', 'parallel', 'port', 'support', 'such', 'as', 'for', 'a', 'printer', 'select', 'thi', 'option', 'either']
# clear need parallel port support such as for a printer select thi option either
# sentence ['will', 'use', 'the', 'hardwar', 'option', 'in', 'with', 'a', 'printer']
# clear will use the hardwar option in with a printer
# sentence ['that', 'not', 'all', 'the', 'parallel', 'port', 'can', 'be', 'use', 'for', 'As', 'an', 'exampl', 'the']
# clear that not all the parallel port can be use for As an exampl the
# sentence ['I', 'did', 'with', 'the', 'telescop', 'compani', 'parallel', 'port', 'support', 'as', 'the']
# clear I did with the telescop compani parallel port support as the
# sentence ['awar', 'thi', 'kernel', 'configur', 'option', 'onli', 'a', 'driver', 'avail', 'for']
# clear awar thi kernel configur option onli a driver avail for
# sentence ['the', 'parallel', 'port', 'the', 'comput', 'the', 'mode', 'for', 'the', 'port', 'or']
# clear the parallel port the comput the mode for the port or
# sentence ['the', 'major', 'of', 'modern', 'the', 'mode', 'is', 'the', 'default', 'and', 'will']
# clear the major of modern the mode is the default and will
# sentence ['work', 'just', 'fine', 'if', 'you', 'have', 'commun', 'with', 'your', 'printer']
# clear work just fine if you have commun with your printer
# sentence ['follow', 'a', 'kernel', 'recompil', 'tri', 'the', 'mode', 'of', 'your', 'printer', 'in', 'the']
# clear follow a kernel recompil tri the mode of your printer in the
# sentence ['a']
# clear a
# sentence ['is', 'an', 'extens', 'network', 'statist', 'collector', 'the', 'network']
# clear is an extens network statist collector the network
# sentence ['interfac', 'in', 'promiscu', 'mode', 'and', 'the', 'data', 'stream', 'after', 'it', 'off', 'the']
# clear interfac in promiscu mode and the data stream after it off the
# sentence ['appropri', 'protocol', 'then', 'the', 'at']
# clear appropri protocol then the at
# sentence ['either', 'in', 'a', 'progress', 'bar', 'mode', 'or', 'as', 'raw', 'statist', 'it']
# clear either in a progress bar mode or as raw statist it
# sentence ['statist', 'both', 'entropi', 'and']
# clear statist both entropi and
# sentence ['univers', 'statist', 'test', 'test', 'is', 'a', 'veri', 'good', 'and', 'comprehens']
# clear univers statist test test is a veri good and comprehens
# sentence ['measur', 'of', 'entropi', 'but', 'a', 'larg', 'amount', 'of', 'data', 'the', 'statist']
# clear measur of entropi but a larg amount of data the statist
# sentence ['I', 'am', 'the', 'web', 'master', 'for', 'health', 'care', 'camp', 'in', 'the', 'state', 'of', 'utah']
# clear I am the web master for health care camp in the state of utah
# sentence ['the', 'for', 'and', 'with', 'about']
# clear the for and with about
# sentence ['diabet', 'a', 'year', 'and', 'their', 'have', 'educ', 'famili']
# clear diabet a year and their have educ famili
# sentence ['support', 'diet', 'and', 'most', 'import', 'is', 'camp', 'the', 'place', 'where']
# clear support diet and most import is camp the place where
# sentence ['are', 'a', 'total', 'non', 'profit', 'camp', 'that', 'all', 'money', 'from', 'into', 'our']
# clear are a total non profit camp that all money from into our
# sentence ['camp', 'pay', 'no', 'to']
# clear camp pay no to
# sentence ['and', 'that', 'make', 'our', 'camp', 'possibl', 'even', 'me', 'the', 'lowli']
# clear and that make our camp possibl even me the lowli
# sentence ['recent', 'decid', 'to', 'pull', 'access', 'to', 'our', 'photo', 'page', 'due', 'to', 'a', 'password']
# clear recent decid to pull access to our photo page due to a password
# sentence ['protect', 'give', 'out', 'a', 'password', 'to', 'all', 'so', 'that', 'they', 'can', 'see']
# clear protect give out a password to all so that they can see
# sentence ['of', 'camp', 'while', 'the', 'session', 'are', 'happen', 'do', 'not', 'howev', 'what']
# clear of camp while the session are happen do not howev what
# sentence ['are', 'look', 'for', 'someon', 'in', 'the', 'state', 'to', 'help', 'our', 'camp', 'by', 'web']
# clear are look for someon in the state to help our camp by web
# sentence ['space', 'it', 'may', 'not', 'be', 'your', 'organ', 'but', 'I', 'know', 'peopl', 'and']
# clear space it may not be your organ but I know peopl and
# sentence ['and', 'I', 'think', 'someon', 'there', 'may', 'know', 'someon', 'who', 'would', 'be', 'abl']
# clear and I think someon there may know someon who would be abl
# sentence ['can', 'still', 'have', 'access', 'to', 'the', 'public', 'part', 'of', 'our', 'site', 'that', 'not']
# clear can still have access to the public part of our site that not
# sentence ['I', 'have', 'the', 'of', 'diabet', 'want', 'to', 'see', 'of']
# clear I have the of diabet want to see of
# sentence ['is', 'a', 'full', 'site', 'relat', 'to', 'on', 'mobil']
# clear is a full site relat to on mobil
# sentence ['and', 'inform', 'for', 'to', 'the']
# clear and inform for to the
# sentence ['list', 'inform', 'on', 'wearabl']
# clear list inform on wearabl
# sentence ['access', 'and', 'on', 'cell', 'to', 'be', 'a', 'great', 'resourc', 'for', 'all']
# clear access and on cell to be a great resourc for all
# sentence ['of', 'and', 'use', 'inform', 'for', 'take', 'your', 'on', 'the']
# clear of and use inform for take your on the
# sentence []
# clear
# sentence []
# clear
# sentence ['a']
# clear a
# sentence ['chang', 'your', 'deliveri', 'address', 'pleas']
# clear chang your deliveri address pleas
# sentence ['page', 'of', 'the', 'monik', 'by', 'doe', 'not', 'impli', 'endors', 'of']
# clear page of the monik by doe not impli endors of
# sentence ['the']
# clear the
# sentence ['is', 'an', 'employ', 'for', 'further', 'inform', 'pleas']
# clear is an employ for further inform pleas
# sentence ['refer', 'to', 'the', 'in', 'the']
# clear refer to the in the
# sentence ['which', 'group', 'is', 'strong', 'and', 'alway', 'look', 'for', 'stuff', 'to', 'make', 'their', 'person', 'and', 'profession', 'run', 'smoother']
# clear which group is strong and alway look for stuff to make their person and profession run smoother
# [Lockergnome Windows Daily]  Brilliant Mistakes
#
#
# sentence []
# clear
#
#
#
# sentence []
# clear
# sentence ['the', 'most', 'power', 'icon']
# clear the most power icon
# sentence ['editor', 'manag', 'for', 'the', 'platform', 'the', 'icon', 'addict', 'I']
# clear editor manag for the platform the icon addict I
# sentence ['for', 'your', 'I', 'have', 'yet', 'to', 'receiv', 'one']
# clear for your I have yet to receiv one
# sentence ['you', 'been', 'wait', 'for', 'the', 'right', 'motiv', 'about', 'a']
# clear you been wait for the right motiv about a
# sentence ['nice', 'littl', 'contest', 'some', 'of', 'the', 'most', 'power', 'on']
# clear nice littl contest some of the most power on
# sentence ['the', 'the', 'deal', 'you', 'creat', 'five', 'or', 'more']
# clear the the deal you creat five or more
# sentence ['between', 'now', 'and', 'the', 'end', 'of', 'juli', 'them', 'to', 'your']
# clear between now and the end of juli them to your
# sentence ['account', 'under', 'and']
# clear account under and
# sentence ['one', 'of', 'the', 'five', 'may', 'pick', 'it', 'the', 'panel', 'myself']
# clear one of the five may pick it the panel myself
# sentence ['each', 'pick', 'our', 'favorit', 'set', 'the', 'will', 'not']
# clear each pick our favorit set the will not
# sentence ['onli', 'receiv', 'one', 'copi', 'of', 'but', 'some']
# clear onli receiv one copi of but some
# sentence ['of', 'their', 'will', 'get', 'with', 'a', 'futur', 'version', 'of', 'the']
# clear of their will get with a futur version of the
# sentence ['is', 'by', 'the', 'origin', 'author', 'so', 'do']
# clear is by the origin author so do
# sentence ['hold', 'back', 'your', 'chanc', 'at', 'fame', 'and', 'fortun', 'at', 'least']
# clear hold back your chanc at fame and fortun at least
# sentence ['fame', 'and', 'free']
# clear fame and free
# sentence ['Ah', 'the', 'life', 'of', 'a', 'pieter', 'just', 'the', 'new']
# clear Ah the life of a pieter just the new
# sentence ['today', 'much', 'more', 'conveni', 'than', 'the', 'offici', 'sorri']
# clear today much more conveni than the offici sorri
# sentence ['I', 'just', 'do', 'like', 'browser', 'I', 'also', 'gave']
# clear I just do like browser I also gave
# sentence ['anoth', 'go', 'I', 'have', 'use', 'it', 'sinc', 'alway', 'been', 'a']
# clear anoth go I have use it sinc alway been a
# sentence ['great', 'piec', 'of', 'but', 'I', 'did', 'realiz', 'it', 'wa', 'good']
# clear great piec of but I did realiz it wa good
# sentence ['the', 'speed', 'increas', 'been', 'quit', 'notic', 'even', 'on', 'shadow']
# clear the speed increas been quit notic even on shadow
# sentence ['my', 'machin', 'is', 'brilliant', 'so', 'is']
# clear my machin is brilliant so is
# sentence ['me', 'access', 'to', 'instant', 'special', 'effect', 'a', 'shop', 'for', 'digit']
# clear me access to instant special effect a shop for digit
# sentence ['photo', 'fun', 'I', 'still', 'debat', 'whether', 'or', 'not', 'to', 'instal', 'the', 'latest']
# clear photo fun I still debat whether or not to instal the latest
# sentence ['java', 'to', 'be', 'unobtrus', 'on', 'my', 'test', 'machin']
# clear java to be unobtrus on my test machin
# sentence ['which', 'is', 'good', 'to', 'see', 'I', 'do', 'want', 'browser', 'integr', 'I', 'just']
# clear which is good to see I do want browser integr I just
# sentence ['wan', 'na', 'run', 'that', 'awesom', 'art', 'program', 'and']
# clear wan na run that awesom art program and
# sentence ['is', 'avail', 'for']
# clear is avail for
# sentence ['X', 'grab', 'it', 'if', 'your', 'boss', 'doe', 'know']
# clear X grab it if your boss doe know
# sentence ['as', 'much', 'as', 'should']
# clear as much as should
# sentence ['deal', 'with', 'today', 'and', 'I', 'not', 'pay', 'ani']
# clear deal with today and I not pay ani
# sentence ['way', 'to', 'go', 'and', 'I', 'hope', 'and', 'pray', 'that', 'more', 'record', 'will']
# clear way to go and I hope and pray that more record will
# sentence ['eventu', 'catch', 'on', 'to', 'the', 'craze', 'the', 'is', 'more', 'than', 'a']
# clear eventu catch on to the craze the is more than a
# sentence ['place', 'for', 'a', 'pamphlet', 'the']
# clear place for a pamphlet the
# sentence ['knowledg', 'the', 'is', 'still', 'in', 'it', 'infanc', 'the']
# clear knowledg the is still in it infanc the
# sentence ['creativ', 'and', 'commerc', 'the', 'one', 'thing', 'the', 'is']
# clear creativ and commerc the one thing the is
# sentence ['a', 'fad', 'potenti', 'is', 'limitless', 'as', 'long', 'as', 'it', 'remain']
# clear a fad potenti is limitless as long as it remain
# sentence ['flexibl', 'and', 'not', 'by', 'ani', 'one', 'compani']
# clear flexibl and not by ani one compani
# sentence ['thing', 'got', 'me', 'more', 'than', 'a', 'littl', 'combin', 'with', 'the']
# clear thing got me more than a littl combin with the
# sentence ['could', 'veri', 'well', 'be', 'the', 'thing', 'that']
# clear could veri well be the thing that
# sentence ['peopl', 'away', 'from', 'the', 'platform', 'in', 'as', 'much', 'as', 'I', 'hate']
# clear peopl away from the platform in as much as I hate
# sentence ['to', 'admit', 'it', 'and', 'music', 'unwittingli']
# clear to admit it and music unwittingli
# sentence ['I', 'best', 'not', 'find', 'out', 'that', 'you', 'part', 'of', 'the', 'problem']
# clear I best not find out that you part of the problem
# sentence ['lister', 'the', 'best', 'thing', 'about', 'thi', 'recip', 'holder', 'the']
# clear lister the best thing about thi recip holder the
# sentence ['convers', 'calcul', 'I', 'alway', 'how', 'mani']
# clear convers calcul I alway how mani
# sentence ['were', 'in', 'a', 'gallon', 'are', 'a', 'few', 'delici', 'alreadi']
# clear were in a gallon are a few delici alreadi
# sentence ['includ', 'to', 'help', 'you', 'start', 'your', 'collect', 'of']
# clear includ to help you start your collect of
# sentence ['is', 'nice', 'divid', 'into', 'too', 'a', 'salad']
# clear is nice divid into too a salad
# sentence ['click', 'quot', 'quot', 'can', 'also', 'make', 'shop']
# clear click quot quot can also make shop
# sentence ['the', 'print', 'capabl', 'is', 'nice', 'too', 'sinc', 'I', 'assum']
# clear the print capabl is nice too sinc I assum
# sentence ['most', 'of', 'you', 'do', 'keep', 'your', 'comput', 'next', 'to', 'the', 'stove', 'quot', 'you']
# clear most of you do keep your comput next to the stove quot you
# sentence ['have', 'an', 'comput', 'with', 'or', 'with', 'the']
# clear have an comput with or with the
# sentence ['latest', 'version', 'of', 'then', 'you', 'can', 'the', 'version', 'with', 'no']
# clear latest version of then you can the version with no
# sentence ['support', 'sinc', 'your', 'comput', 'all', 'the', 'necessari', 'quot']
# clear support sinc your comput all the necessari quot
# sentence ['moon', 'and', 'is', 'it', 'all', 'the', 'other', 'have']
# clear moon and is it all the other have
# sentence ['realli', 'cool', 'for', 'their', 'respect', 'moon', 's', 'but', 'is']
# clear realli cool for their respect moon s but is
# sentence ['simpli', 'to', 'as', 'quot', 'moon', 'quot', 'should', 'chang', 'it', 'to', 'someth']
# clear simpli to as quot moon quot should chang it to someth
# sentence ['like', 'quot', 'joey', 'quot', 'mind', 'me', 'I']
# clear like quot joey quot mind me I
# sentence ['wa', 'just', 'look', 'at', 'thi', 'new', 'applic', 'a', 'graphic']
# clear wa just look at thi new applic a graphic
# sentence ['represent', 'of', 'everi', 'planet', 'in', 'our', 'solar', 'system', 'as', 'oppos', 'to']
# clear represent of everi planet in our solar system as oppos to
# sentence ['everi', 'planet', 'in', 'the', 'system', 'and', 'it', 'also']
# clear everi planet in the system and it also
# sentence ['detail', 'inform', 'such', 'as', 'the', 'planet', 'distanc', 'from', 'the', 'sun']
# clear detail inform such as the planet distanc from the sun
# sentence ['it', 'volum', 'mass', 'and', 'graviti', 'in', 'relat', 'to', 'I', 'found']
# clear it volum mass and graviti in relat to I found
# sentence ['most', 'interest', 'wa', 'how', 'long', 'a', 'singl', 'quot', 'day', 'quot', 'on', 'differ']
# clear most interest wa how long a singl quot day quot on differ
# sentence ['you', 'know', 'one', 'day', 'on', 'pluto', 'is', 'equal', 'to', 'six', 'day', 'on']
# clear you know one day on pluto is equal to six day on
# sentence ['I', 'guess', 'he', 'chip', 'and', 'dale', 'around', 'the', 'christma', 'tree']
# clear I guess he chip and dale around the christma tree
# sentence ['for', 'longer', 'than', 'we', 'thought']
# clear for longer than we thought
# sentence ['quot', 'an', 'abbrevi', 'for', 'is', 'a', 'great']
# clear quot an abbrevi for is a great
# sentence ['client', 'server', 'packag', 'remot', 'network', 'access', 'to']
# clear client server packag remot network access to
# sentence ['graphic', 'you', 'may', 'allow', 'yourself', 'to', 'access']
# clear graphic you may allow yourself to access
# sentence ['your', 'machin', 'from', 'everywher', 'provid', 'that', 'your', 'machin', 'is']
# clear your machin from everywher provid that your machin is
# sentence ['connect', 'to', 'the', 'is', 'free', 'under', 'the']
# clear connect to the is free under the
# sentence ['and', 'it', 'avail', 'on', 'most', 'the']
# clear and it avail on most the
# sentence ['origin', 'distribut', 'can', 'be', 'at', 'the', 'T', 'research']
# clear origin distribut can be at the T research
# sentence ['site', 'you', 'can', 'find', 'enhanc', 'version', 'of']
# clear site you can find enhanc version of
# sentence ['grown', 'from', 'the', 'project', 'which', 'is']
# clear grown from the project which is
# sentence ['to', 'work', 'over', 'slow', 'network', 'such', 'as']
# clear to work over slow network such as
# sentence ['link', 'origin', 'may', 'be', 'veri', 'slow', 'when', 'your']
# clear link origin may be veri slow when your
# sentence ['connect', 'is', 'not', 'fast', 'enough', 'with', 'you', 'can', 'work', 'remot']
# clear connect is not fast enough with you can work remot
# sentence ['almost', 'in', 'real', 'time', 'in', 'most']
# clear almost in real time in most
# sentence ['also', 'mani', 'other']
# clear also mani other
# sentence ['and', 'bug', 'over', 'quot']
# clear and bug over quot
# sentence ['I', 'found', 'some', 'realli', 'cool', 'to', 'gener', 'site', 'navig']
# clear I found some realli cool to gener site navig
# sentence ['and', 'I', 'thought', 'you', 'might', 'be', 'interest', 'in', 'learn', 'about', 'it']
# clear and I thought you might be interest in learn about it
# sentence ['are', 'sever', 'on', 'the', 'compani', 'site', 'as', 'well', 'as', 'on', 'my']
# clear are sever on the compani site as well as on my
# sentence ['own', 'a', 'small', 'about', 'it', 'perhap', 'you', 'be', 'interest']
# clear own a small about it perhap you be interest
# sentence ['in', 'run', 'thi', 'in', 'a', 'futur', 'issu', 'all', 'seen', 'a']
# clear in run thi in a futur issu all seen a
# sentence ['lot', 'of', 'realli', 'cool', 'site', 'navig', 'with', 'text', 'neat']
# clear lot of realli cool site navig with text neat
# sentence ['effect', 'and', 'the', 'like', 'of', 'them', 'requir', 'a']
# clear effect and the like of them requir a
# sentence ['combin', 'of', 'and', 'to', 'build', 'which', 'is']
# clear combin of and to build which is
# sentence ['that', 'goe', 'way', 'beyond', 'some', 'of', 'us', 'last', 'it', 'possibl', 'to', 'easili']
# clear that goe way beyond some of us last it possibl to easili
# sentence ['gener', 'just', 'such', 'a', 'menu', 'with', 'some', 'veri', 'to']
# clear gener just such a menu with some veri to
# sentence ['enter', 'the', 'data', 'you', 'want', 'to', 'use']
# clear enter the data you want to use
# sentence ['come', 'in', 'a', 'version', 'or', 'you', 'can', 'get', 'a', 'fulli']
# clear come in a version or you can get a fulli
# sentence ['licens', 'version', 'for', 'a', 'licens', 'for', 'the']
# clear licens version for a licens for the
# sentence ['licens', 'the', 'biggest', 'differ', 'the', 'licens']
# clear licens the biggest differ the licens
# sentence ['version', 'you', 'get', 'the', 'abil', 'to', 'save', 'a', 'menu', 'you', 'so']
# clear version you get the abil to save a menu you so
# sentence ['you', 'can', 'modifi', 'it', 'later', 'onli', 'altern', 'if', 'you', 'want', 'to']
# clear you can modifi it later onli altern if you want to
# sentence ['make', 'even', 'a', 'simpl', 'chang', 'to', 'a', 'menu', 'by', 'the']
# clear make even a simpl chang to a menu by the
# sentence ['version', 'is', 'to', 'creat', 'the', 'whole', 'menu', 'again', 'from', 'scratch', 'or', 'dive']
# clear version is to creat the whole menu again from scratch or dive
# sentence ['into', 'the', 'and', 'of', 'the', 'code', 'and', 'that']
# clear into the and of the code and that
# sentence ['the', 'like', 'a', 'novel', 'so', 'that']
# clear the like a novel so that
# sentence ['could', 'potenti', 'be', 'a', 'nightmar', 'I', 'decid', 'to', 'buy', 'the', 'fulli']
# clear could potenti be a nightmar I decid to buy the fulli
# sentence ['licens', 'version', 'and', 'I', 'realli', 'glad', 'I', 'did', 'if', 'I', 'sound', 'like']
# clear licens version and I realli glad I did if I sound like
# sentence ['a', 'commerci', 'for', 'the', 'compani', 'I', 'do', 'work', 'for', 'them', 'or', 'stand', 'to', 'be']
# clear a commerci for the compani I do work for them or stand to be
# sentence ['in', 'ani', 'way', 'for', 'them', 'I', 'just', 'think', 'thi']
# clear in ani way for them I just think thi
# sentence ['menu', 'system', 'is', 'the', 'thing', 'to', 'come', 'along', 'in', 'a', 'while']
# clear menu system is the thing to come along in a while
# sentence ['it', 'are', 'just', 'for', 'and']
# clear it are just for and
# sentence ['or', 'spell', 'silli', 'by', 'turn', 'the', 'calcul', 'upsid']
# clear or spell silli by turn the calcul upsid
# sentence ['down', 'about', 'out', 'the', 'on', 'your', 'new', 'car']
# clear down about out the on your new car
# sentence ['about', 'the', 'for', 'your', 'wheat', 'farm', 'you']
# clear about the for your wheat farm you
# sentence ['out', 'there', 'need', 'a', 'nice', 'calcul', 'of', 'cours']
# clear out there need a nice calcul of cours
# sentence ['what', 'footbal', 'fan', 'would', 'like', 'to', 'calcul', 'the', 'pass', 'for']
# clear what footbal fan would like to calcul the pass for
# sentence ['hi', 'or', 'her', 'favorit', 'quarterback', 'it', 'like', 'I', 'all', 'over', 'the']
# clear hi or her favorit quarterback it like I all over the
# sentence ['map', 'here', 'it', 'becaus', 'thi', 'site', 'link', 'to', 'all', 'of']
# clear map here it becaus thi site link to all of
# sentence ['calcul', 'for', 'all', 'of', 'peopl', 'me', 'it', 'all', 'up']
# clear calcul for all of peopl me it all up
# sentence ['to', 'a', 'uniqu', 'and', 'use', 'site']
# clear to a uniqu and use site
# sentence ['how', 'to', 'thwart', 'fals', 'steve']
# clear how to thwart fals steve
# sentence ['quot', 'a', 'recent', 'articl', 'over', 'the', 'issu', 'it', 'wa']
# clear quot a recent articl over the issu it wa
# sentence ['state', 'that', 'when', 'a', 'credit', 'card', 'illeg', 'the', 'owner', 'of', 'that']
# clear state that when a credit card illeg the owner of that
# sentence ['card', 'is', 'respons', 'for', 'the', 'first', 'that']
# clear card is respons for the first that
# sentence ['veri', 'few', 'peopl', 'know', 'about', 'is', 'that', 'there', 'is', 'a', 'feder', 'provis']
# clear veri few peopl know about is that there is a feder provis
# sentence ['in', 'the', 'bank', 'industri', 'E', 'E']
# clear in the bank industri E E
# sentence ['that', 'all', 'will', 'err', 'in']
# clear that all will err in
# sentence ['favor', 'of', 'the', 'custom', 'account', 'holder', 'that', 'if', 'your']
# clear favor of the custom account holder that if your
# sentence ['card', 'is', 'use', 'without', 'your', 'permiss', 'you', 'are', 'not']
# clear card is use without your permiss you are not
# sentence ['respons', 'for', 'ani', 'of', 'the', 'suggest', 'is', 'never', 'to', 'use']
# clear respons for ani of the suggest is never to use
# sentence ['a', 'credit', 'card', 'and', 'onli', 'use', 'your', 'bank', 'debit', 'card', 'way', 'if']
# clear a credit card and onli use your bank debit card way if
# sentence ['someon', 'your', 'number', 'you', 'are', 'not', 'liabl', 'for', 'ani', 'of', 'the']
# clear someon your number you are not liabl for ani of the
# sentence ['quot', 'for', 'more', 'inform', 'pleas', 'refer', 'to', 'on']
# clear quot for more inform pleas refer to on
# sentence ['thi', 'tip', 'onli', 'to', 'peopl']
# clear thi tip onli to peopl
# sentence ['live', 'in', 'the', 'you', 'have', 'been', 'watch', 'your']
# clear live in the you have been watch your
# sentence ['like', 'a', 'hawk', 'late', 'you', 'be', 'wise', 'to', 'start', 'soon', 'theft', 'is']
# clear like a hawk late you be wise to start soon theft is
# sentence ['a', 'grow', 'concern', 'my', 'wallet', 'wa', 'stolen', 'I', 'found']
# clear a grow concern my wallet wa stolen I found
# sentence ['to', 'be', 'a', 'godsend']
# clear to be a godsend
# sentence ['which', 'group', 'is', 'strong', 'and', 'alway', 'look', 'for', 'stuff', 'to', 'make', 'their', 'person', 'and', 'profession', 'run', 'smoother']
# clear which group is strong and alway look for stuff to make their person and profession run smoother
# sentence ['now', 'we', 'see', 'the', 'stori', 'of', 'the', 'ugli', 'shoe', 'unfold', 'befor', 'our', 'veri', 'footwear', 'wa', 'outcast', 'from', 'the', 'group', 'ago', 'and', 'been', 'veri', 'depress', 'ever', 'sinc', 'my', 'shoe']
# clear now we see the stori of the ugli shoe unfold befor our veri footwear wa outcast from the group ago and been veri depress ever sinc my shoe
# sentence ['your', 'life', 'by', 'ten', 'but', 'you', 'spend', 'of', 'them', 'do', 'it']
# clear your life by ten but you spend of them do it
# Your Daily Dilbert 07/10/2002
#
#
# sentence []
# clear
#
#
#
# sentence ['error']
# clear error
# sentence ['to', 'the', 'version', 'of', 'the']
# clear to the version of the
# sentence ['which', 'the', 'comic', 'strip', 'as', 'a', 'graphic', 'but', 'your', 'mail', 'system']
# clear which the comic strip as a graphic but your mail system
# sentence ['either', 'ca', 'support', 'or', 'is', 'set', 'up', 'to', 'remov', 'content', 'for']
# clear either ca support or is set up to remov content for
# sentence ['more', 'inform', 'contact', 'your', 'servic', 'provid', 'or', 'mail']
# clear more inform contact your servic provid or mail
# sentence ['system', 'administr']
# clear system administr
# sentence ['chang', 'to', 'a', 'plain', 'text', 'subscript', 'modifi', 'your', 'account']
# clear chang to a plain text subscript modifi your account
# sentence ['at']
# clear at
# sentence ['the', 'plain', 'text', 'option', 'toward', 'the', 'bottom', 'of', 'the', 'modif']
# clear the plain text option toward the bottom of the modif
# sentence ['page']
# clear page
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# sentence ['function', 'rand', 'n']
# clear function rand n
# sentence []
# clear
# sentence ['seed', 'seed']
# clear seed seed
# sentence ['return', 'seed', 'n']
# clear return seed n
# sentence []
# clear
# sentence ['now', 'new']
# clear now new
# sentence ['seed']
# clear seed
# sentence ['same', 'rand']
# clear same rand
# sentence ['script', 'from', 'old']
# clear script from old
# sentence ['hide', 'from', 'old']
# clear hide from old
# sentence []
# clear
# sentence []
# clear
# sentence []
# clear
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-32-f03435a3aad9> in <module>
#       1 if __name__ == "__main__":
#       2     #train_and_test_model(r"./emails/*/*")
# ----> 3     train_and_test_model(r"./test/*/*")
#       4
#
# <ipython-input-29-c07d19cd309a> in train_and_test_model(path)
#       1 def train_and_test_model(path):
#       2
# ----> 3     data = get_subject_data(path)
#       4     random.seed(0)      # just so you get the same answers as me
#       5     train_data, test_data = split_data(data, 0.75)
#
# <ipython-input-27-830b7e043491> in get_subject_data(path)
#      26                 elif start == True  and is_html(line) == None:
#      27                     subject = subject_regex.sub("", line).strip()
# ---> 28                     subject = filters(subject)
#      29                     data.append((subject, is_spam))
#      30
#
# <ipython-input-26-1fce83cad4f7> in filters(line)
#       6     sentence  = []
#       7     for w in arr_words:
# ----> 8         if w in words.words() :
#       9             sentence.append(ps.stem(w))
#      10     #endFor
#
# /opt/conda/lib/python3.7/site-packages/nltk/corpus/reader/wordlist.py in words(self, fileids, ignore_lines_startswith)
#      23         return [
#      24             line
# ---> 25             for line in line_tokenize(self.raw(fileids))
#      26             if not line.startswith(ignore_lines_startswith)
#      27         ]
#
# /opt/conda/lib/python3.7/site-packages/nltk/corpus/reader/wordlist.py in <listcomp>(.0)
#      24             line
#      25             for line in line_tokenize(self.raw(fileids))
# ---> 26             if not line.startswith(ignore_lines_startswith)
#      27         ]
#      28
#
# KeyboardInterrupt:
